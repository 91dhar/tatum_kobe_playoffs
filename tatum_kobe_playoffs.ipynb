# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('tatum_playoffs.xlsx')

# %%
df
# Out:
#     Career Game  Season Game       Date Series   Tm  Opp  G# Result  GS  \
# 0             1            1 2018-04-15    EC1  BOS  MIL   1      W   1
# 1             2            2 2018-04-17    EC1  BOS  MIL   2      W   1
# 2             3            3 2018-04-20    EC1  BOS  MIL   3      L   1
# 3             4            4 2018-04-22    EC1  BOS  MIL   4      L   1
# 4             5            5 2018-04-24    EC1  BOS  MIL   5      W   1
# ..          ...          ...        ...    ...  ...  ...  ..    ...  ..
# 89           90           16 2023-05-21    ECF  BOS  MIA   3      L   1
# 90           91           17 2023-05-23    ECF  BOS  MIA   4      W   1
# 91           92           18 2023-05-25    ECF  BOS  MIA   5      W   1
# 92           93           19 2023-05-27    ECF  BOS  MIA   6      W   1
# 93           94           20 2023-05-29    ECF  BOS  MIA   7      L   1
#
#                      MP  ...  DRB  TRB  AST  STL  BLK  TOV  PF  PTS  GmSc  +/-
# ...

# %%
plt.figure(figsize=(12, 6))
plt.plot(df['Career Game'], df['PTS'], marker='o', linestyle='-', color='b')
plt.xlabel('Career Game')
plt.ylabel('Points Scored')
plt.title('Jayson Tatum - Points Scored Over Career')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(df['Career Game'], df['3P%'], marker='o', linestyle='-', color='g')
plt.xlabel('Career Game')
plt.ylabel('3-Point Shooting Percentage')
plt.title('Jayson Tatum - 3-Point Shooting Percentage Over Career')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hist(df['GmSc'], bins=20, color='purple', alpha=0.7)
plt.xlabel('Game Score (GmSc)')
plt.ylabel('Frequency')
plt.title('Distribution of Jayson Tatum\'s Game Score (GmSc)')
plt.grid(True)
plt.show()

# %%
import pandas as pd

df.sort_values(by='Career Game', inplace=True)

# Creating a list of sections
sections = [(i, i + 9) for i in range(1, 95, 10)]  # Sections: [(1, 10), (11, 20), ... , (81, 90), (91, 94)]

# Initializing a dictionary to store the total points for each section
section_totals = {}

# Iterating through the sections and calculate total points
for section_start, section_end in sections:
    section_name = f"{section_start}-{section_end}"
    section_df = df[(df['Career Game'] >= section_start) & (df['Career Game'] <= section_end)]
    total_points = section_df['PTS'].sum()
    section_totals[section_name] = total_points

# Creating a DataFrame from the section_totals dictionary
section_df = pd.DataFrame.from_dict(section_totals, orient='index', columns=['Total Points'])

print(section_df)
# Out:
#         Total Points
# 1-10             181
# 11-20            185
# 21-30            187
# 31-40            243
# 41-50            282
# 51-60            288
# 61-70            238
# 71-80            252
# 81-90            281
# 91-100            99

# %%
import pandas as pd
import matplotlib.pyplot as plt

df.sort_values(by='Career Game', inplace=True)

# Creating a list of sections
sections = [(i, i + 9) for i in range(1, 95, 10)]  # Sections: [(1, 10), (11, 20), ... , (81, 90), (91, 94)]

# Initializing a dictionary to store the total points for each section
section_totals = {}

# Iterating through the sections and calculate total points
for section_start, section_end in sections:
    section_name = f"{section_start}-{section_end}"
    section_df = df[(df['Career Game'] >= section_start) & (df['Career Game'] <= section_end)]
    total_points = section_df['PTS'].sum()
    section_totals[section_name] = total_points

# Creating a DataFrame from the section_totals dictionary
section_df = pd.DataFrame.from_dict(section_totals, orient='index', columns=['Total Points'])

# Creating a bar graph
plt.figure(figsize=(12, 6))
plt.bar(section_df.index, section_df['Total Points'], color='green')
plt.xlabel('Career Game Sections')
plt.ylabel('Total Points')
plt.title('Total Points in Career Game Sections for Jayson Tatum')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df.sort_values(by='Career Game', inplace=True)

# Creating a list of sections
sections = [(i, i + 9) for i in range(1, 95, 10)]  # Sections: [(1, 10), (11, 20), ... , (81, 90), (91, 94)]

# Initializng a dictionary to store the cumulative total points
cumulative_totals = {}

# Initializing a variable to keep track of cumulative total
cumulative_total = 0

# Iterating through the sections and calculate cumulative total points
for section_start, section_end in sections:
    section_name = f"{section_start}-{section_end}"
    section_df = df[(df['Career Game'] >= section_start) & (df['Career Game'] <= section_end)]
    total_points = section_df['PTS'].sum()
    cumulative_total += total_points
    cumulative_totals[section_name] = cumulative_total

# Creating a DataFrame from the cumulative_totals dictionary
cumulative_df = pd.DataFrame.from_dict(cumulative_totals, orient='index', columns=['Cumulative Total Points'])

# Creating a bar graph
plt.figure(figsize=(12, 6))
plt.bar(cumulative_df.index, cumulative_df['Cumulative Total Points'], color='green')
plt.xlabel('Career Game Sections')
plt.ylabel('Cumulative Total Points')
plt.title('Cumulative Total Points in Career Game Sections for Jayson Tatum')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

print(cumulative_df)
# Out:
#         Cumulative Total Points
# 1-10                        181
# 11-20                       366
# 21-30                       553
# 31-40                       796
# 41-50                      1078
# 51-60                      1366
# 61-70                      1604
# 71-80                      1856
# 81-90                      2137
# 91-100                     2236

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df.sort_values(by='Career Game', inplace=True)

# Creating a list of sections
sections = [(i, i + 9) for i in range(1, 95, 10)]  # Sections: [(1, 10), (11, 20), ... , (81, 90), (91, 94)]

# Initializing a dictionary to store the cumulative total points
cumulative_totals = {}

# Initializing a variable to keep track of cumulative total
cumulative_total = 0

# Iterating through the sections and calculate cumulative total points
for section_start, section_end in sections:
    section_name = f"{section_start}-{section_end}"
    section_df = df[(df['Career Game'] >= section_start) & (df['Career Game'] <= section_end)]
    total_points = section_df['PTS'].sum()
    cumulative_total += total_points
    cumulative_totals[section_name] = cumulative_total
print(cumulative_df)

# Creating a DataFrame from the cumulative_totals dictionary
cumulative_df = pd.DataFrame.from_dict(cumulative_totals, orient='index', columns=['Cumulative Total Points'])

# Calculating the trendline using numpy.polyfit
x_values = np.arange(len(cumulative_df))
y_values = cumulative_df['Cumulative Total Points']
trendline = np.polyfit(x_values, y_values, 1)  # Linear trendline

# Creating a bar graph
plt.figure(figsize=(12, 6))
plt.bar(cumulative_df.index, cumulative_df['Cumulative Total Points'], color='skyblue', label='Cumulative Total Points')
plt.plot(x_values, trendline[0] * x_values + trendline[1], color='orange', linestyle='--', label='Trendline')
plt.xlabel('Career Game Sections')
plt.ylabel('Cumulative Total Points')
plt.title('Cumulative Total Points in Career Game Sections for Jayson Tatum with Trendline')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.legend()
plt.show()
# Out:
#         Tatum Cumulative Total Points  Kobe Cumulative Total Points
# 1-10                              181                            89
# 11-20                             366                           170
# 21-30                             553                           383
# 31-40                             796                           597
# 41-50                            1078                           793
# 51-60                            1366                          1117
# 61-70                            1604                          1362
# 71-80                            1856                          1633
# 81-90                            2137                          1930
# 91-100                           2236                          2064

# %%
df
# Out:
#     Career Game  Season Game       Date Series   Tm  Opp  G# Result  GS  \
# 0             1            1 2018-04-15    EC1  BOS  MIL   1      W   1
# 1             2            2 2018-04-17    EC1  BOS  MIL   2      W   1
# 2             3            3 2018-04-20    EC1  BOS  MIL   3      L   1
# 3             4            4 2018-04-22    EC1  BOS  MIL   4      L   1
# 4             5            5 2018-04-24    EC1  BOS  MIL   5      W   1
# ..          ...          ...        ...    ...  ...  ...  ..    ...  ..
# 89           90           16 2023-05-21    ECF  BOS  MIA   3      L   1
# 90           91           17 2023-05-23    ECF  BOS  MIA   4      W   1
# 91           92           18 2023-05-25    ECF  BOS  MIA   5      W   1
# 92           93           19 2023-05-27    ECF  BOS  MIA   6      W   1
# 93           94           20 2023-05-29    ECF  BOS  MIA   7      L   1
#
#                      MP  ...  DRB  TRB  AST  STL  BLK  TOV  PF  PTS  GmSc  +/-
# ...

# %%
plt.figure(figsize=(12, 6))
plt.plot(df['Career Game'], df['TOV'], marker='o', linestyle='-', color='g')
plt.xlabel('Career Game')
plt.ylabel('Turnovers')
plt.title('Jayson Tatum - Turnovers - Playoffs Career')
plt.grid(True)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Creating the plot for turnovers
plt.figure(figsize=(12, 6))
plt.plot(df['Career Game'], df['TOV'], marker='o', linestyle='-', color='g', label='Turnovers')
plt.xlabel('Career Game')
plt.ylabel('Turnovers')
plt.title('Jayson Tatum - Turnovers - Playoffs Career')

# Calculating the degree of the polynomial trendline (you can adjust this)
degree = 5

# Defining the number of games in each trend section
games_per_section = 10

# Fitting the polynomial trendline
x_values = df['Career Game']
y_values = df['TOV']
coefficients = np.polyfit(x_values, y_values, degree)
polynomial = np.poly1d(coefficients)

# Creating x values for the trendline (with 10-game increments)
x_trendline = np.arange(x_values.min(), x_values.max() + 1, games_per_section)

# Calculating the y values for the trendline
y_trendline = polynomial(x_trendline)

# Adding the trendline to the plot
plt.plot(x_trendline, y_trendline, color='orange', linestyle='--', label=f'Polynomial Trendline (Degree {degree})')
x_tick_values = np.arange(x_values.min(), x_values.max() + 1, 10)
plt.xticks(x_tick_values)
plt.grid(True)
plt.legend()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Creating the plot for turnovers as a step line plot
plt.figure(figsize=(12, 6))
plt.step(df['Career Game'], df['TOV'], where='mid', color='g', label='Turnovers')
plt.xlabel('Career Game')
plt.ylabel('Turnovers')
plt.title('Jayson Tatum - Turnovers - Playoffs Career')

# Calculating the degree of the polynomial trendline (you can adjust this)
degree = 3

# Defining the number of games in each trend section
games_per_section = 10

# Fitting the polynomial trendline
x_values = df['Career Game']
y_values = df['TOV']
coefficients = np.polyfit(x_values, y_values, degree)
polynomial = np.poly1d(coefficients)

# Creating x values for the trendline (with 10-game increments)
x_trendline = np.arange(x_values.min(), x_values.max() + 1, games_per_section)

# Calculating the y values for the trendline
y_trendline = polynomial(x_trendline)

# Adding the trendline to the plot as a step line
plt.step(x_trendline, y_trendline, where='mid', color='orange', linestyle='--', label=f'Polynomial Trendline (Degree {degree})')

# Setting custom x-axis tick values to represent increments of 10 games
x_tick_values = np.arange(x_values.min(), x_values.max() + 1, 10)
plt.xticks(x_tick_values)

plt.grid(True)
plt.legend()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Creating the stem plot for turnovers
plt.figure(figsize=(12, 6))
plt.stem(df['Career Game'], df['TOV'], linefmt='g-', markerfmt='go', basefmt=' ', label='Turnovers')
plt.xlabel('Career Game')
plt.ylabel('Turnovers')
plt.title('Jayson Tatum - Turnovers - Playoffs Career')

# Calculating the degree of the polynomial trendline (you can adjust this)
degree = 10  # You can adjust this for a higher-degree curve

# Fitting the polynomial trendline
x_values = df['Career Game']
y_values = df['TOV']
coefficients = np.polyfit(x_values, y_values, degree)
polynomial = np.poly1d(coefficients)

# Creating x values for the trendline
x_trendline = np.linspace(x_values.min(), x_values.max(), 100)

# Calculating the y values for the trendline
y_trendline = polynomial(x_trendline)

# Plotting the trendline
plt.plot(x_trendline, y_trendline, color='purple', linestyle='--', label=f'Polynomial Trendline (Degree {degree})')

plt.grid(True)
plt.legend()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Creating the stem plot for points
plt.figure(figsize=(12, 6))
plt.stem(df['Career Game'], df['PTS'], linefmt='g-', markerfmt='go', basefmt=' ', label='Turnovers')
plt.xlabel('Career Game')
plt.ylabel('Points')
plt.title('Jayson Tatum - Points - Playoffs Career')

# Calculating the degree of the polynomial trendline (you can adjust this)
degree = 10  # You can adjust this for a higher-degree curve

# Fitting the polynomial trendline
x_values = df['Career Game']
y_values = df['PTS']
coefficients = np.polyfit(x_values, y_values, degree)
polynomial = np.poly1d(coefficients)

# Creating x values for the trendline
x_trendline = np.linspace(x_values.min(), x_values.max(), 100)

# Calculating the y values for the trendline
y_trendline = polynomial(x_trendline)

# Plotting the trendline
plt.plot(x_trendline, y_trendline, color='purple', linestyle='--', label=f'Polynomial Trendline (Degree {degree})')
x_tick_values = np.arange(x_values.min(), x_values.max() + 1, 10)
plt.xticks(x_tick_values)
plt.grid(True)
plt.legend()
plt.show()

# %%
import pandas as pd

# Loading dataset for Kobe
new_player_df = pd.read_excel('kobe_playoffs.xlsx')

# %%
new_player_df
# Out:
#     Career Game  Season Game       Date Series   Tm  Opp  G# Result  GS  \
# 0             1            1 1997-04-25    WC1  LAL  POR   1      W   0
# 1             2            2 1997-04-27    WC1  LAL  POR   2      W   0
# 2             3            3 1997-04-30    WC1  LAL  POR   3      L   0
# 3             4            4 1997-05-02    WC1  LAL  POR   4      W   0
# 4             5            5 1997-05-04    WCS  LAL  UTA   1      L   0
# ..          ...          ...        ...    ...  ...  ...  ..    ...  ..
# 89           90            5 2003-04-29    WC1  LAL  MIN   5      W   1
# 90           91            6 2003-05-01    WC1  LAL  MIN   6      W   1
# 91           92            7 2003-05-05    WCS  LAL  SAS   1      L   1
# 92           93            8 2003-05-07    WCS  LAL  SAS   2      L   1
# 93           94            9 2003-05-09    WCS  LAL  SAS   3      W   1
#
#                      MP  ...  DRB  TRB  AST  STL  BLK  TOV  PF  PTS  GmSc  +/-
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load data for the first player from an Excel file
tatum_df = pd.read_excel('tatum_playoffs.xlsx')

# Load data for the new player from a different Excel file
kobe_df = pd.read_excel('kobe_playoffs.xlsx')

# Calculating average points per game for both players
avg_points_tatum = tatum_df['PTS'].mean()
avg_points_kobe = kobe_df['PTS'].mean()

print(avg_points_tatum)
print(avg_points_kobe)

# Creating a bar chart to compare the average points
plt.figure(figsize=(8, 6))
plt.bar(['Jayson Tatum', 'Kobe Bryant'], [avg_points_tatum, avg_points_kobe], color=['blue', 'green'])
plt.xlabel('Player')
plt.ylabel('Average Points Per Game')
plt.title('Comparison of Average Points Per Game')
plt.show()
# Out:
# 23.78723404255319
# 21.95744680851064

# %%
import matplotlib.pyplot as plt
import numpy as np

# Defining the data
players = ['Tatum', 'Kobe', 'Bill Russell']
points = [0, 5, 11]  # Replace with the actual points data
colors = ['blue', 'purple', 'green']  # Define colors for each player

# Creating a bar graph with different colors
plt.figure(figsize=(8, 6))
bars = plt.bar(players, points, color=colors)
plt.xlabel('Players')
plt.ylabel('Championships')

# Calculating and plot a trendline using a line plot
x_values = np.arange(len(players))
coefficients = np.polyfit(x_values, points, 1)
trendline = np.poly1d(coefficients)
plt.plot(x_values, trendline(x_values), color='red', linestyle='--', label='Trendline')

# Applying labels to the bars (optional)
for bar, point in zip(bars, points):
    plt.text(bar.get_x() + bar.get_width() / 2 - 0.1, point + 0.5, str(point), color='black', fontsize=12)

plt.legend()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

tatum_df = pd.read_excel('tatum_playoffs.xlsx')

kobe_df = pd.read_excel('kobe_playoffs.xlsx')

# Creating the stem plot for points for the first player
plt.figure(figsize=(12, 6))
plt.stem(tatum_df['Career Game'], tatum_df['PTS'], linefmt='g-', markerfmt='go', basefmt=' ', label='Jayson Tatum')
plt.xlabel('Career Game')
plt.ylabel('Points')
plt.title('Jayson Tatum - Points - Playoffs Career')

# Creating the stem plot for points for the second player
plt.figure(figsize=(12, 6))
plt.stem(kobe_df['Career Game'], kobe_df['PTS'], linefmt='b-', markerfmt='bo', basefmt=' ', label='Kobe Bryant')
plt.xlabel('Career Game')
plt.ylabel('Points')
plt.title('Kobe Bryant - Points - Playoffs Career')

# Calculating the degree of the polynomial trendline (you can adjust this)
degree = 10  # You can adjust this for a higher-degree curve

# Fitting the polynomial trendline for the first player
x_values_tatum = tatum_df['Career Game']
y_values_tatum = tatum_df['PTS']
coefficients_tatum = np.polyfit(x_values_tatum, y_values_tatum, degree)
polynomial_tatum = np.poly1d(coefficients_tatum)

# Fitting the polynomial trendline for the second player
x_values_kobe = kobe_df['Career Game']
y_values_kobe = kobe_df['PTS']
coefficients_kobe = np.polyfit(x_values_kobe, y_values_kobe, degree)
polynomial_kobe = np.poly1d(coefficients_kobe)

# Creating x values for the trendline
x_trendline_tatum = np.linspace(x_values_tatum.min(), x_values_tatum.max(), 100)
x_trendline_kobe = np.linspace(x_values_kobe.min(), x_values_kobe.max(), 100)

# Calculating the y values for the trendline for both players
y_trendline_tatum = polynomial_tatum(x_trendline_tatum)
y_trendline_kobe = polynomial_kobe(x_trendline_kobe)

# Plotting the trendline for the first player
plt.figure(figsize=(12, 6))
plt.plot(x_trendline_tatum, y_trendline_tatum, color='green', linestyle='--', label=f'Tatum Trendline (Degree {degree})')
plt.xlabel('Career Game')
plt.ylabel('Points')
plt.title('Jayson Tatum - Points - Trendline Comparison')

# Plotting the trendline for the second player
plt.plot(x_trendline_kobe, y_trendline_kobe, color='purple', linestyle='--', label=f'Kobe Trendline (Degree {degree})')
plt.xlabel('Career Game')
plt.ylabel('Points')
plt.title('Playoffs Career Points - Trendline Comparison')

# Setting x-axis tick values for both players
x_tick_values_tatum = np.arange(x_values_tatum.min(), x_values_tatum.max() + 1, 10)
x_tick_values_kobe = np.arange(x_values_kobe.min(), x_values_kobe.max() + 1, 10)

plt.xticks(x_tick_values_tatum)
plt.grid(True)
plt.legend()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

tatum_df = pd.read_excel('tatum_playoffs.xlsx')

kobe_df = pd.read_excel('kobe_playoffs.xlsx')

# Creating a figure for the plot
plt.figure(figsize=(12, 6))

# Plotting the stem plot for points for the first player
plt.stem(tatum_df['Career Game'], tatum_df['PTS'], linefmt='g-', markerfmt='go', basefmt=' ', label='Jayson Tatum')

# Plotting the stem plot for points for the second player
plt.stem(kobe_df['Career Game'], kobe_df['PTS'], linefmt='b-', markerfmt='bo', basefmt=' ', label='Kobe Bryant')

# Calculating the degree of the polynomial trendline (you can adjust this)
degree = 10  # You can adjust this for a higher-degree curve

# Fitting the polynomial trendline for the first player
x_values_tatum = tatum_df['Career Game']
y_values_tatum = tatum_df['PTS']
coefficients_tatum = np.polyfit(x_values_tatum, y_values_tatum, degree)
polynomial_tatum = np.poly1d(coefficients_tatum)

# Fitting the polynomial trendline for the second player
x_values_kobe = kobe_df['Career Game']
y_values_kobe = kobe_df['PTS']
coefficients_kobe = np.polyfit(x_values_kobe, y_values_kobe, degree)
polynomial_kobe = np.poly1d(coefficients_kobe)

# Creating x values for the trendline
x_trendline_tatum = np.linspace(x_values_tatum.min(), x_values_tatum.max(), 100)
x_trendline_kobe = np.linspace(x_values_kobe.min(), x_values_kobe.max(), 100)

# Calculating the y values for the trendline for both players
y_trendline_tatum = polynomial_tatum(x_trendline_tatum)
y_trendline_kobe = polynomial_kobe(x_trendline_kobe)

# Plotting the trendline for the first player
plt.plot(x_trendline_tatum, y_trendline_tatum, color='green', linestyle='--', label=f'Tatum Trendline (Degree {degree})')

# Plotting the trendline for the second player
plt.plot(x_trendline_kobe, y_trendline_kobe, color='purple', linestyle='--', label=f'Kobe Trendline (Degree {degree})')

# Setting x-axis tick values
x_tick_values_tatum = np.arange(x_values_tatum.min(), x_values_tatum.max() + 1, 10)
x_tick_values_kobe = np.arange(x_values_kobe.min(), x_values_kobe.max() + 1, 10)

plt.xticks(np.concatenate((x_tick_values_tatum, x_tick_values_kobe)))  # Combine x tick values

# Adding labels, title, and legend
plt.xlabel('Career Game')
plt.ylabel('Points')
plt.title('Playoffs Career Points - Trendline Comparison')
plt.grid(True)
plt.legend()

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

tatum_df = pd.read_excel('tatum_playoffs.xlsx')

kobe_df = pd.read_excel('kobe_playoffs.xlsx')

# Creating a figure for the plot
plt.figure(figsize=(12, 6))

# Plotting the stem plot for points for the first player
plt.stem(tatum_df['Career Game'], tatum_df['TOV'], linefmt='g-', markerfmt='go', basefmt=' ', label='Jayson Tatum')

# Plotting the stem plot for points for the second player
plt.stem(kobe_df['Career Game'], kobe_df['TOV'], linefmt='b-', markerfmt='bo', basefmt=' ', label='Kobe Bryant')

# Calculating the degree of the polynomial trendline (you can adjust this)
degree = 10  # You can adjust this for a higher-degree curve

# Fitting the polynomial trendline for the first player
x_values_tatum = tatum_df['Career Game']
y_values_tatum = tatum_df['TOV']
coefficients_tatum = np.polyfit(x_values_tatum, y_values_tatum, degree)
polynomial_tatum = np.poly1d(coefficients_tatum)

# Fitting the polynomial trendline for the second player
x_values_kobe = kobe_df['Career Game']
y_values_kobe = kobe_df['TOV']
coefficients_kobe = np.polyfit(x_values_kobe, y_values_kobe, degree)
polynomial_kobe = np.poly1d(coefficients_kobe)

# Creating x values for the trendline
x_trendline_tatum = np.linspace(x_values_tatum.min(), x_values_tatum.max(), 100)
x_trendline_kobe = np.linspace(x_values_kobe.min(), x_values_kobe.max(), 100)

# Calculating the y values for the trendline for both players
y_trendline_tatum = polynomial_tatum(x_trendline_tatum)
y_trendline_kobe = polynomial_kobe(x_trendline_kobe)

# Plotting the trendline for the first player
plt.plot(x_trendline_tatum, y_trendline_tatum, color='green', linestyle='--', label=f'Tatum Trendline (Degree {degree})')

# Plotting the trendline for the second player
plt.plot(x_trendline_kobe, y_trendline_kobe, color='purple', linestyle='--', label=f'Kobe Trendline (Degree {degree})')

# Setting x-axis tick values
x_tick_values_tatum = np.arange(x_values_tatum.min(), x_values_tatum.max() + 1, 10)
x_tick_values_kobe = np.arange(x_values_kobe.min(), x_values_kobe.max() + 1, 10)

plt.xticks(np.concatenate((x_tick_values_tatum, x_tick_values_kobe)))  # Combine x tick values

# Adding labels, title, and legend
plt.xlabel('Career Game')
plt.ylabel('Turnovers')
plt.title('Playoffs Turnovers - Trendline Comparison')
plt.grid(True)
plt.legend()

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

tatum_df = pd.read_excel('tatum_playoffs.xlsx') 

kobe_df = pd.read_excel('kobe_playoffs.xlsx')

# Calculate average points per game for both players
GS_tatum = tatum_df['GS'].sum()
GS_kobe = kobe_df['GS'].sum()

print('In the first 94 playoff games of their career...')
print(f'Jayson HIM Tatum started {GS_tatum} playoff games for the Boston Celtics')
print(f'Kobe Bryant started {GS_kobe} playoff games for the Lakers')

# Create a bar chart to compare the average points
plt.figure(figsize=(8, 6))
plt.bar(['Jayson Tatum', 'Kobe Bryant'], [GS_tatum, GS_kobe], color=['green', 'purple'])
plt.xlabel('Player')
plt.ylabel('Playoffs Games Started')
plt.title('Comparison of Playoffs Games Started')
plt.show()
# Out:
# In the first 94 playoff games of their career...
# Jayson HIM Tatum started 94 playoff games for the Boston Celtics
# Kobe Bryant started 74 playoff games for the Lakers

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

tatum_df = pd.read_excel('tatum_playoffs.xlsx')

kobe_df = pd.read_excel('kobe_playoffs.xlsx')

# Create a figure for the plot
plt.figure(figsize=(12, 6))

# Create overlapping density plots for career points of both players
sns.kdeplot(data=tatum_df['PTS'], color='green', label='Jayson Tatum', shade=True)
sns.kdeplot(data=kobe_df['PTS'], color='purple', label='Kobe Bryant', shade=True)

# Add labels, title, and legend
plt.xlabel('Career Points')
plt.ylabel('Density')
plt.title('Density Plot of Playoffs Career Points')
plt.legend()

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

tatum_df = pd.read_excel('tatum_playoffs.xlsx')

kobe_df = pd.read_excel('kobe_playoffs.xlsx')

# Create a figure for the plot
plt.figure(figsize=(12, 6))

# Create stacked histograms for career points of both players on a log scale
plt.hist([tatum_df['PTS'], kobe_df['PTS']], bins=20, color=['green', 'purple'], label=['Jayson Tatum', 'Kobe Bryant'], stacked=True, log=True)

# Add labels, title, and legend
plt.xlabel('Career Points')
plt.ylabel('Frequency (log scale)')
plt.title('Stacked Histogram of Playoffs Career Points on Log Scale')
plt.legend()

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

tatum_df = pd.read_excel('tatum_playoffs.xlsx')

kobe_df = pd.read_excel('kobe_playoffs.xlsx')

# Create a figure for the plot
plt.figure(figsize=(12, 6))

# Plot the time series data for points for the first player with error bands
plt.errorbar(tatum_df['Career Game'], tatum_df['PTS'], yerr=1.0, fmt='go-', label='Jayson Tatum')

# Plot the time series data for points for the second player with error bands
plt.errorbar(kobe_df['Career Game'], kobe_df['PTS'], yerr=1.0, fmt='bo-', label='Kobe Bryant')

# Add labels, title, and legend
plt.xlabel('Career Game')
plt.ylabel('Points')
plt.title('Playoffs Career Points - Time Series with Error Bands')
plt.grid(True)
plt.legend()

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

tatum_df = pd.read_excel('tatum_playoffs.xlsx')

kobe_df = pd.read_excel('kobe_playoffs.xlsx')

# Create a figure for the plot
plt.figure(figsize=(12, 6))

# Define the number of bars and bar width
num_bars = len(tatum_df)
bar_width = 0.35

# Create an array of x values for the bars
x_values = np.arange(num_bars)

# Plot the grouped barplots for career points for both players
plt.bar(x_values - bar_width/2, tatum_df['PTS'], bar_width, label='Jayson Tatum', color='green')
plt.bar(x_values + bar_width/2, kobe_df['PTS'], bar_width, label='Kobe Bryant', color='blue')

# Calculate the trendline for Jayson Tatum's data
degree_tatum = 10
coefficients_tatum = np.polyfit(x_values, tatum_df['PTS'], degree_tatum)
polynomial_tatum = np.poly1d(coefficients_tatum)
y_trendline_tatum = polynomial_tatum(x_values)

# Calculate the trendline for Kobe Bryant's data
degree_kobe = 10
coefficients_kobe = np.polyfit(x_values, kobe_df['PTS'], degree_kobe)
polynomial_kobe = np.poly1d(coefficients_kobe)
y_trendline_kobe = polynomial_kobe(x_values)

# Plot the trendlines
plt.plot(x_values, y_trendline_tatum, color='black', linestyle='--', label=f'Tatum Trendline (Degree {degree_tatum})')
plt.plot(x_values, y_trendline_kobe, color='purple', linestyle='--', label=f'Kobe Trendline (Degree {degree_kobe})')

# Add labels, title, and legend
plt.xlabel('Career Game')
plt.ylabel('Points')
plt.title('Playoffs Career Points - Grouped Barplots with Trendlines')
plt.grid(True)
plt.legend()

# Set x-axis tick values in a sequence of 10 games
x_tick_values = np.arange(0, num_bars, 10)  # Start at 0, increment by 10
x_tick_labels = x_tick_values + 1

plt.xticks(x_tick_values, x_tick_labels)

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

tatum_df = pd.read_excel('tatum_playoffs.xlsx')

kobe_df = pd.read_excel('kobe_playoffs.xlsx')

# Calculate cumulative sum of points for each player
tatum_df['Cumulative Points'] = tatum_df['PTS'].cumsum()
kobe_df['Cumulative Points'] = kobe_df['PTS'].cumsum()

# Create a figure for the plot
plt.figure(figsize=(12, 6))

# Plot the cumulative points for Jayson Tatum
plt.plot(tatum_df['Career Game'], tatum_df['Cumulative Points'], label='Jayson Tatum', color='green')

# Plot the cumulative points for Kobe Bryant
plt.plot(kobe_df['Career Game'], kobe_df['Cumulative Points'], label='Kobe Bryant', color='blue')

# Add labels, title, and legend
plt.xlabel('Career Game')
plt.ylabel('Cumulative Points')
plt.title('Cumulative Points Comparison After Every 10 Games')
plt.grid(True)
plt.legend()

# Set x-axis tick values in a sequence of 10 games
x_tick_values = np.arange(0, len(tatum_df), 10)  # Start at 0, increment by 10
x_tick_labels = x_tick_values + 1  

plt.xticks(x_tick_values, x_tick_labels)

plt.show()

# %%
import pandas as pd

tatum_df = pd.read_excel('tatum_playoffs.xlsx')

kobe_df = pd.read_excel('kobe_playoffs.xlsx')

# Calculate cumulative sum of points for each player
tatum_df['Cumulative Points'] = tatum_df['PTS'].cumsum()
kobe_df['Cumulative Points'] = kobe_df['PTS'].cumsum()

# Create a DataFrame to store the cumulative points comparison
cumulative_points_df = pd.DataFrame({
    'Career Game': tatum_df['Career Game'],  # Assuming 'Career Game' is a common column
    'Jayson Tatum Cumulative Points': tatum_df['Cumulative Points'],
    'Kobe Bryant Cumulative Points': kobe_df['Cumulative Points']
})

print(cumulative_points_df)
# Out:
#     Career Game  Jayson Tatum Cumulative Points  Kobe Bryant Cumulative Points
# 0             1                              19                              2
# 1             2                              23                              8
# 2             3                              37                             30
# 3             4                              58                             30
# 4             5                              66                             33
# ..          ...                             ...                            ...
# 89           90                            2137                           1930
# 90           91                            2170                           1961
# 91           92                            2191                           1998
# 92           93                            2222                           2025
# 93           94                            2236                           2064
#
# [94 rows x 3 columns]

# %%
import pandas as pd

tatum_df = pd.read_excel('tatum_playoffs.xlsx')

kobe_df = pd.read_excel('kobe_playoffs.xlsx')

# Calculate cumulative sum of points for each player
tatum_df['Cumulative Points'] = tatum_df['PTS'].cumsum()
kobe_df['Cumulative Points'] = kobe_df['PTS'].cumsum()

# Calculate cumulative points after every 10 games
tatum_cumulative_10_games = tatum_df.groupby(tatum_df.index // 10 * 10)['Cumulative Points'].last()
kobe_cumulative_10_games = kobe_df.groupby(kobe_df.index // 10 * 10)['Cumulative Points'].last()

# Create a DataFrame to store the cumulative points comparison after every 10 games
cumulative_points_10_games_df = pd.DataFrame({
    'Games': tatum_cumulative_10_games.index + 1,
    'Tatum Cumulative Points': tatum_cumulative_10_games.values,
    'Kobe Cumulative Points': kobe_cumulative_10_games.values
})

print(cumulative_points_10_games_df)
# Out:
#    Games  Tatum Cumulative Points  Kobe Cumulative Points
# 0      1                      181                      89
# 1     11                      366                     170
# 2     21                      553                     383
# 3     31                      796                     597
# 4     41                     1078                     793
# 5     51                     1366                    1117
# 6     61                     1604                    1362
# 7     71                     1856                    1633
# 8     81                     2137                    1930
# 9     91                     2236                    2064

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Creating a figure and axis for the chart
fig, ax = plt.subplots(figsize=(10, 6))

# Plot the cumulative points data as a stem chart with stacked bars and values on top
stem_tatum = ax.stem(cumulative_points_10_games_df['Games'], cumulative_points_10_games_df['Tatum Cumulative Points'], linefmt='g-', markerfmt='go', basefmt=' ')
stem_kobe = ax.stem(cumulative_points_10_games_df['Games'], cumulative_points_10_games_df['Kobe Cumulative Points'], linefmt='b-', markerfmt='bo', basefmt=' ')

# Add labels and title to the chart
ax.set_xlabel('Games (Every 10 Games)')
ax.set_ylabel('Cumulative Points')
ax.set_title('Cumulative Points Comparison After Every 10 Games')

# Add values on top of each stem for Tatum
for i, val in enumerate(cumulative_points_10_games_df['Tatum Cumulative Points']):
    ax.annotate(str(val), xy=(cumulative_points_10_games_df['Games'][i], val), xytext=(0, 5), textcoords='offset points', va='bottom', ha='center')

# Add values on top of each stem for Kobe
for i, val in enumerate(cumulative_points_10_games_df['Kobe Cumulative Points']):
    ax.annotate(str(val), xy=(cumulative_points_10_games_df['Games'][i], val), xytext=(0, 5), textcoords='offset points', va='bottom', ha='center')

# Fit a polynomial trendline (you can adjust the degree)
degree = 2
x_values = cumulative_points_10_games_df['Games']
y_values_tatum = cumulative_points_10_games_df['Tatum Cumulative Points']
y_values_kobe = cumulative_points_10_games_df['Kobe Cumulative Points']

coefficients_tatum = np.polyfit(x_values, y_values_tatum, degree)
coefficients_kobe = np.polyfit(x_values, y_values_kobe, degree)

polynomial_tatum = np.poly1d(coefficients_tatum)
polynomial_kobe = np.poly1d(coefficients_kobe)

# Create x values for the trendline
x_trendline = np.linspace(x_values.min(), x_values.max(), 100)

# Calculate the y values for the trendline for both players
y_trendline_tatum = polynomial_tatum(x_trendline)
y_trendline_kobe = polynomial_kobe(x_trendline)

# Plot the trendline for Tatum
ax.plot(x_trendline, y_trendline_tatum, color='green', linestyle='--', label=f'Tatum Trendline (Degree {degree})')

# Plot the trendline for Kobe
ax.plot(x_trendline, y_trendline_kobe, color='purple', linestyle='--', label=f'Kobe Trendline (Degree {degree})')

plt.legend()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression

# Sort the dataframes by 'Career Game'
tatum_df.sort_values(by='Career Game', inplace=True)
kobe_df.sort_values(by='Career Game', inplace=True)

# Creating a list of sections
sections = [(i, i + 9) for i in range(1, 95, 10)]  # Sections: [(1, 10), (11, 20), ... , (81, 90), (91, 94)]

# Initializng dictionaries to store the cumulative total points for each player
cumulative_totals_tatum = {}
cumulative_totals_kobe = {}

# Initializing variables to keep track of cumulative totals
cumulative_total_tatum = 0
cumulative_total_kobe = 0

# Iterating through the sections and calculate cumulative total points for each player
for section_start, section_end in sections:
    section_name = f"{section_start}-{section_end}"
    
    # Filter data for Jayson Tatum
    section_tatum_df = tatum_df[(tatum_df['Career Game'] >= section_start) & (tatum_df['Career Game'] <= section_end)]
    total_points_tatum = section_tatum_df['PTS'].sum()
    cumulative_total_tatum += total_points_tatum
    cumulative_totals_tatum[section_name] = cumulative_total_tatum
    
    # Filter data for Kobe Bryant
    section_kobe_df = kobe_df[(kobe_df['Career Game'] >= section_start) & (kobe_df['Career Game'] <= section_end)]
    total_points_kobe = section_kobe_df['PTS'].sum()
    cumulative_total_kobe += total_points_kobe
    cumulative_totals_kobe[section_name] = cumulative_total_kobe

# Creating DataFrames from the cumulative_totals dictionaries for each player
cumulative_tatum_df = pd.DataFrame.from_dict(cumulative_totals_tatum, orient='index', columns=['Tatum Cumulative Total Points'])
cumulative_kobe_df = pd.DataFrame.from_dict(cumulative_totals_kobe, orient='index', columns=['Kobe Cumulative Total Points'])

# Combine both DataFrames into one
cumulative_df = pd.concat([cumulative_tatum_df, cumulative_kobe_df], axis=1)

# Creating a bar graph for both players
plt.figure(figsize=(10, 6))
bar_width = 0.4
index = range(len(cumulative_df))

plt.bar(index, cumulative_df['Tatum Cumulative Total Points'], width=bar_width, color='green', label='Jayson Tatum')
plt.bar([i + bar_width for i in index], cumulative_df['Kobe Cumulative Total Points'], width=bar_width, color='black', label='Kobe Bryant')

plt.xlabel('Career Game Sections')
plt.ylabel('Cumulative Total Points')
plt.title('Cumulative Total Points in Career Game Sections')
plt.xticks([i + bar_width/2 for i in index], cumulative_df.index, rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.legend()

# Adding trendlines
x_values = np.array(index)
x_values_combined = np.concatenate((x_values, x_values + bar_width))
y_values_tatum = cumulative_df['Tatum Cumulative Total Points'].values
y_values_kobe = cumulative_df['Kobe Cumulative Total Points'].values

model_tatum = LinearRegression().fit(x_values.reshape(-1, 1), y_values_tatum)
model_kobe = LinearRegression().fit(x_values.reshape(-1, 1), y_values_kobe)

plt.plot(x_values_combined, model_tatum.predict(x_values_combined.reshape(-1, 1)), linestyle='--', color='green', label='Tatum Trendline')
plt.plot(x_values_combined, model_kobe.predict(x_values_combined.reshape(-1, 1)), linestyle='--', color='purple', label='Kobe Trendline')

# Adding values on top of each bar
for i, val in enumerate(cumulative_df['Tatum Cumulative Total Points']):
    plt.text(i, val + 50, str(val), ha='center', va='bottom', fontsize=9, fontweight='bold', color='red')

for i, val in enumerate(cumulative_df['Kobe Cumulative Total Points']):
    plt.text(i + bar_width, val + 50, str(val), ha='center', va='bottom', fontsize=9, fontweight='bold', color='red')

plt.tight_layout()
plt.show()

print(cumulative_df)
# Out:
#         Tatum Cumulative Total Points  Kobe Cumulative Total Points
# 1-10                              181                            89
# 11-20                             366                           170
# 21-30                             553                           383
# 31-40                             796                           597
# 41-50                            1078                           793
# 51-60                            1366                          1117
# 61-70                            1604                          1362
# 71-80                            1856                          1633
# 81-90                            2137                          1930
# 91-100                           2236                          2064

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression

# Sort the dataframes by 'Career Game'
tatum_df.sort_values(by='Career Game', inplace=True)
kobe_df.sort_values(by='Career Game', inplace=True)

# Creating a list of sections
sections = [(i, i + 9) for i in range(1, 95, 10)]  # Sections: [(1, 10), (11, 20), ... , (81, 90), (91, 94)]

# Initializng dictionaries to store the cumulative total TRB for each player
cumulative_totals_tatum = {}
cumulative_totals_kobe = {}

# Initializing variables to keep track of cumulative totals
cumulative_total_tatum = 0
cumulative_total_kobe = 0

# Iterating through the sections and calculate cumulative total TRB for each player
for section_start, section_end in sections:
    section_name = f"{section_start}-{section_end}"
    
    # Filter data for Jayson Tatum
    section_tatum_df = tatum_df[(tatum_df['Career Game'] >= section_start) & (tatum_df['Career Game'] <= section_end)]
    total_trb_tatum = section_tatum_df['TRB'].sum()
    cumulative_total_tatum += total_trb_tatum
    cumulative_totals_tatum[section_name] = cumulative_total_tatum
    
    # Filter data for Kobe Bryant
    section_kobe_df = kobe_df[(kobe_df['Career Game'] >= section_start) & (kobe_df['Career Game'] <= section_end)]
    total_trb_kobe = section_kobe_df['TRB'].sum()
    cumulative_total_kobe += total_trb_kobe
    cumulative_totals_kobe[section_name] = cumulative_total_kobe

# Creating DataFrames from the cumulative_totals dictionaries for each player
cumulative_tatum_df = pd.DataFrame.from_dict(cumulative_totals_tatum, orient='index', columns=['Tatum Cumulative Total TRB'])
cumulative_kobe_df = pd.DataFrame.from_dict(cumulative_totals_kobe, orient='index', columns=['Kobe Cumulative Total TRB'])

# Combine both DataFrames into one
cumulative_df = pd.concat([cumulative_tatum_df, cumulative_kobe_df], axis=1)

# Creating a bar graph for both players
plt.figure(figsize=(10, 6))
bar_width = 0.4
index = range(len(cumulative_df))

plt.bar(index, cumulative_df['Tatum Cumulative Total TRB'], width=bar_width, color='green', label='Jayson Tatum')
plt.bar([i + bar_width for i in index], cumulative_df['Kobe Cumulative Total TRB'], width=bar_width, color='black', label='Kobe Bryant')

plt.xlabel('Career Game Sections')
plt.ylabel('Cumulative Total TRB')
plt.title('Cumulative Total TRB in Career Game Sections')
plt.xticks([i + bar_width/2 for i in index], cumulative_df.index, rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.legend()

# Adding trendlines
x_values = np.array(index)
x_values_combined = np.concatenate((x_values, x_values + bar_width))
y_values_tatum = cumulative_df['Tatum Cumulative Total TRB'].values
y_values_kobe = cumulative_df['Kobe Cumulative Total TRB'].values

model_tatum = LinearRegression().fit(x_values.reshape(-1, 1), y_values_tatum)
model_kobe = LinearRegression().fit(x_values.reshape(-1, 1), y_values_kobe)

plt.plot(x_values_combined, model_tatum.predict(x_values_combined.reshape(-1, 1)), linestyle='--', color='green', label='Tatum Trendline')
plt.plot(x_values_combined, model_kobe.predict(x_values_combined.reshape(-1, 1)), linestyle='--', color='purple', label='Kobe Trendline')

# Adding values on top of each bar
for i, val in enumerate(cumulative_df['Tatum Cumulative Total TRB']):
    plt.text(i, val + 50, str(val), ha='center', va='bottom', fontsize=9, fontweight='bold', color='red')

for i, val in enumerate(cumulative_df['Kobe Cumulative Total TRB']):
    plt.text(i + bar_width, val + 50, str(val), ha='center', va='bottom', fontsize=9, fontweight='bold', color='red')

plt.tight_layout()
plt.show()

print(cumulative_df)
# Out:
#         Tatum Cumulative Total TRB  Kobe Cumulative Total TRB
# 1-10                            47                         12
# 11-20                           86                         32
# 21-30                          161                         98
# 31-40                          268                        133
# 41-50                          342                        185
# 51-60                          398                        260
# 61-70                          473                        320
# 71-80                          563                        379
# 81-90                          671                        441
# 91-100                         713                        457

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression

# Sort the dataframes by 'Career Game'
tatum_df.sort_values(by='Career Game', inplace=True)
kobe_df.sort_values(by='Career Game', inplace=True)

# Creating a list of sections
sections = [(i, i + 9) for i in range(1, 95, 10)]  # Sections: [(1, 10), (11, 20), ... , (81, 90), (91, 94)]

# Initializng dictionaries to store the cumulative total AST for each player
cumulative_totals_tatum = {}
cumulative_totals_kobe = {}

# Initializing variables to keep track of cumulative totals
cumulative_total_tatum = 0
cumulative_total_kobe = 0

# Iterating through the sections and calculate cumulative total AST for each player
for section_start, section_end in sections:
    section_name = f"{section_start}-{section_end}"
    
    # Filter data for Jayson Tatum
    section_tatum_df = tatum_df[(tatum_df['Career Game'] >= section_start) & (tatum_df['Career Game'] <= section_end)]
    total_ast_tatum = section_tatum_df['AST'].sum()
    cumulative_total_tatum += total_ast_tatum
    cumulative_totals_tatum[section_name] = cumulative_total_tatum
    
    # Filter data for Kobe Bryant
    section_kobe_df = kobe_df[(kobe_df['Career Game'] >= section_start) & (kobe_df['Career Game'] <= section_end)]
    total_ast_kobe = section_kobe_df['AST'].sum()
    cumulative_total_kobe += total_ast_kobe
    cumulative_totals_kobe[section_name] = cumulative_total_kobe

# Creating DataFrames from the cumulative_totals dictionaries for each player
cumulative_tatum_df = pd.DataFrame.from_dict(cumulative_totals_tatum, orient='index', columns=['Tatum Cumulative Total AST'])
cumulative_kobe_df = pd.DataFrame.from_dict(cumulative_totals_kobe, orient='index', columns=['Kobe Cumulative Total AST'])

# Combine both DataFrames into one
cumulative_df = pd.concat([cumulative_tatum_df, cumulative_kobe_df], axis=1)

# Creating a bar graph for both players
plt.figure(figsize=(10, 6))
bar_width = 0.4
index = range(len(cumulative_df))

plt.bar(index, cumulative_df['Tatum Cumulative Total AST'], width=bar_width, color='green', label='Jayson Tatum')
plt.bar([i + bar_width for i in index], cumulative_df['Kobe Cumulative Total AST'], width=bar_width, color='black', label='Kobe Bryant')

plt.xlabel('Career Game Sections')
plt.ylabel('Cumulative Total AST')
plt.title('Cumulative Total AST in Career Game Sections')
plt.xticks([i + bar_width/2 for i in index], cumulative_df.index, rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.legend()

# Adding trendlines
x_values = np.array(index)
x_values_combined = np.concatenate((x_values, x_values + bar_width))
y_values_tatum = cumulative_df['Tatum Cumulative Total AST'].values
y_values_kobe = cumulative_df['Kobe Cumulative Total AST'].values

model_tatum = LinearRegression().fit(x_values.reshape(-1, 1), y_values_tatum)
model_kobe = LinearRegression().fit(x_values.reshape(-1, 1), y_values_kobe)

plt.plot(x_values_combined, model_tatum.predict(x_values_combined.reshape(-1, 1)), linestyle='--', color='green', label='Tatum Trendline')
plt.plot(x_values_combined, model_kobe.predict(x_values_combined.reshape(-1, 1)), linestyle='--', color='purple', label='Kobe Trendline')

# Adding values on top of each bar
for i, val in enumerate(cumulative_df['Tatum Cumulative Total AST']):
    plt.text(i, val + 50, str(val), ha='center', va='bottom', fontsize=9, fontweight='bold', color='red')

for i, val in enumerate(cumulative_df['Kobe Cumulative Total AST']):
    plt.text(i + bar_width, val + 50, str(val), ha='center', va='bottom', fontsize=9, fontweight='bold', color='red')

plt.tight_layout()
plt.show()

print(cumulative_df)
# Out:
#         Tatum Cumulative Total AST  Kobe Cumulative Total AST
# 1-10                            30                         15
# 11-20                           52                         27
# 21-30                           75                         70
# 31-40                          121                        109
# 41-50                          177                        161
# 51-60                          236                        218
# 61-70                          299                        277
# 71-80                          357                        317
# 81-90                          403                        377
# 91-100                         430                        392
